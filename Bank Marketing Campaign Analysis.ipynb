# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank_data = pd.read_csv('/Users/priyanshuporwal/Downloads/bank-additional/bank-additional-full.csv')

# %%
bank_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
# age               41188 non-null int64
# job               41188 non-null object
# marital           41188 non-null object
# education         41188 non-null object
# default           41188 non-null object
# housing           41188 non-null object
# loan              41188 non-null object
# contact           41188 non-null object
# month             41188 non-null object
# day_of_week       41188 non-null object
# duration          41188 non-null int64
# campaign          41188 non-null int64
# pdays             41188 non-null int64
# previous          41188 non-null int64
# poutcome          41188 non-null object
# emp.var.rate      41188 non-null float64
# cons.price.idx    41188 non-null float64
# cons.conf.idx     41188 non-null float64
# euribor3m         41188 non-null float64
# nr.employed       41188 non-null float64
# y                 41188 non-null object
# ...

# %%
bank_data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
bank_data.tail()
# Out:
#        age          job  marital            education default housing loan  \
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41183  cellular   nov         fri  ...         1    999         0
# 41184  cellular   nov         fri  ...         1    999         0
# 41185  cellular   nov         fri  ...         2    999         0
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# ...

# %%
sns.pairplot(bank_data)

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=bank_data['education'])

# %%
sns.countplot(x=bank_data['marital'],hue=bank_data['y'])

# %%
bank_data['age'].describe()
# Out:
# count    41188.00000
# mean        40.02406
# std         10.42125
# min         17.00000
# 25%         32.00000
# 50%         38.00000
# 75%         47.00000
# max         98.00000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(45,25))
sns.countplot(x=bank_data['age'], hue=bank_data['y'])

# %%
sns.barplot(x=bank_data['poutcome'], y = bank_data['previous'])

# %%
sns.catplot(x="housing",y="previous",data=bank_data, kind='bar')

# %%
sns.scatterplot(x="y",y="cons.price.idx",data=bank_data)

# %%
sns.distplot(bank_data['nr.employed'])

# %%
sns.scatterplot(x=bank_data['euribor3m'], y=bank_data['y'] )

# %%
plt.figure(figsize=(20,12))

sns.countplot(x=bank_data['job'], hue=bank_data['y'])

# %%
sns.countplot(bank_data['default'])

# %%
sns.countplot(bank_data['housing'])

# %%
#dataset2 = pd.get_dummies(dataset2, columns = ['education'])
#dataset2['housing'] = dataset2['housing'].map({'yes': 1, 'no': 0})
#dataset2['default'] = dataset2['default'].map({'yes': 1, 'no': 0})
#dataset2['loan'] = dataset2['loan'].map({'yes': 1, 'no': 0})
#dataset_response = pd.DataFrame(dataset['response_binary'])
#dataset2 = pd.merge(dataset2, dataset_response, left_index = True, right_index = True)

# %%
#bank_data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
#data_job = pd.get_dummies(bank_data['job'], drop_first=True)

# %%
#data_marital = pd.get_dummies(bank_data['marital'], drop_first=True)

# %%
#data_education = pd.get_dummies(bank_data['education'], drop_first=True)

# %%
#bank_data1 = bank_data['default'].map({'unknown':1, 'no':0})

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

# %%
bank_data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
bank_data['job']      = labelencoder_X.fit_transform(bank_data['job']) 
bank_data['marital']  = labelencoder_X.fit_transform(bank_data['marital']) 
bank_data['education']= labelencoder_X.fit_transform(bank_data['education']) 
bank_data['default']  = labelencoder_X.fit_transform(bank_data['default']) 
bank_data['housing']  = labelencoder_X.fit_transform(bank_data['housing']) 
bank_data['loan']     = labelencoder_X.fit_transform(bank_data['loan'])

# %%
bank_data.head()
# Out:
#    age  job  marital  education  default  housing  loan    contact month  \
# 0   56    3        1          0        0        0     0  telephone   may
# 1   57    7        1          3        1        0     0  telephone   may
# 2   37    7        1          3        0        2     0  telephone   may
# 3   40    0        1          1        0        0     0  telephone   may
# 4   56    7        1          3        0        0     2  telephone   may
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         mon  ...         1    999         0  nonexistent          1.1
# 1         mon  ...         1    999         0  nonexistent          1.1
# 2         mon  ...         1    999         0  nonexistent          1.1
# 3         mon  ...         1    999         0  nonexistent          1.1
# 4         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
def age(dataframe):
    dataframe.loc[dataframe['age'] <= 32, 'age'] = 1
    dataframe.loc[(dataframe['age'] > 32) & (dataframe['age'] <= 47), 'age'] = 2
    dataframe.loc[(dataframe['age'] > 47) & (dataframe['age'] <= 70), 'age'] = 3
    dataframe.loc[(dataframe['age'] > 70) & (dataframe['age'] <= 98), 'age'] = 4
           
    return dataframe

age(bank_data);

# %%
bank_data.head()
# Out:
#    age  job  marital  education  default  housing  loan    contact month  \
# 0    3    3        1          0        0        0     0  telephone   may
# 1    3    7        1          3        1        0     0  telephone   may
# 2    2    7        1          3        0        2     0  telephone   may
# 3    2    0        1          1        0        0     0  telephone   may
# 4    3    7        1          3        0        0     2  telephone   may
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         mon  ...         1    999         0  nonexistent          1.1
# 1         mon  ...         1    999         0  nonexistent          1.1
# 2         mon  ...         1    999         0  nonexistent          1.1
# 3         mon  ...         1    999         0  nonexistent          1.1
# 4         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
sns.countplot(bank_data['poutcome'])

# %%
bank_data['poutcome']     = labelencoder_X.fit_transform(bank_data['poutcome'])

# %%
bank_data.head()
# Out:
#    age  job  marital  education  default  housing  loan    contact month  \
# 0    3    3        1          0        0        0     0  telephone   may
# 1    3    7        1          3        1        0     0  telephone   may
# 2    2    7        1          3        0        2     0  telephone   may
# 3    2    0        1          1        0        0     0  telephone   may
# 4    3    7        1          3        0        0     2  telephone   may
#
#   day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0         mon  ...         1    999         0         1           1.1
# 1         mon  ...         1    999         0         1           1.1
# 2         mon  ...         1    999         0         1           1.1
# 3         mon  ...         1    999         0         1           1.1
# 4         mon  ...         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
bank_data.rename(columns={'y':'target'}, inplace=True)

# %%
sns.countplot(bank_data['target'])

# %%
bank_data['target'] = bank_data['target'].map({'yes': 1, 'no': 0})

# %%
bank_data.drop(['contact', 'month', 'day_of_week'], axis=1, inplace=True)

# %%
bank_data.head()
# Out:
#    age  job  marital  education  default  housing  loan  duration  campaign  \
# 0    3    3        1          0        0        0     0       261         1
# 1    3    7        1          3        1        0     0       149         1
# 2    2    7        1          3        0        2     0       226         1
# 3    2    0        1          1        0        0     0       151         1
# 4    3    7        1          3        0        0     2       307         1
#
#    pdays  previous  poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0    999         0         1           1.1          93.994          -36.4
# 1    999         0         1           1.1          93.994          -36.4
# 2    999         0         1           1.1          93.994          -36.4
# 3    999         0         1           1.1          93.994          -36.4
# 4    999         0         1           1.1          93.994          -36.4
#
#    euribor3m  nr.employed  target
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = bank_data.drop('target', axis=1)
y = bank_data['target']

# %%
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# <b> Logistic Regression </b>

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression()

# %%
log.fit(X_train, y_train)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predictions = log.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     24492
#            1       0.65      0.39      0.49      3103
#
#     accuracy                           0.91     27595
#    macro avg       0.79      0.68      0.72     27595
# weighted avg       0.90      0.91      0.90     27595

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[23840   652]
#  [ 1895  1208]]

# %% [markdown]
# <b> Random Forest </b>

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=5000)

# %%
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=5000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
predictions_rfc = rfc.predict(X_test)

# %%
print(classification_report(y_test, predictions_rfc))
print(confusion_matrix(y_test, predictions_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95     24492
#            1       0.64      0.52      0.57      3103
#
#     accuracy                           0.91     27595
#    macro avg       0.79      0.74      0.76     27595
# weighted avg       0.91      0.91      0.91     27595
#
# [[23583   909]
#  [ 1490  1613]]

# %%
#from sklearn.utils import resample

# Separate input features and target
y = df.Class
X = df.drop('Class', axis=1)

# setting up testing and training sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=27)

# concatenate our training data back together
X = pd.concat([X_train, y_train], axis=1)

# separate minority and majority classes
not_fraud = X[X.Class==0]
fraud = X[X.Class==1]

# upsample minority
fraud_upsampled = resample(fraud,
                          replace=True, # sample with replacement
                          n_samples=len(not_fraud), # match number in majority class
                          random_state=27) # reproducible results

# combine majority and upsamp

# %% [markdown]
# <b>
# <font color="red">Upsampling of minority</font>
# </b>

# %%
from sklearn.utils import resample

# %%
X = pd.concat([X_train, y_train], axis=1)

# %%
target_yes = X[X['target']==1]
target_no = X[X['target']==0]

# %%
target_yes_upsampled = resample(target_yes,replace=True, n_samples=len(target_no), random_state=27)

# %%
upsampled = pd.concat([target_yes_upsampled, target_no])

# %%
upsampled[upsampled['target']==1].count()
# Out:
# age               12056
# job               12056
# marital           12056
# education         12056
# default           12056
# housing           12056
# loan              12056
# duration          12056
# campaign          12056
# pdays             12056
# previous          12056
# poutcome          12056
# emp.var.rate      12056
# cons.price.idx    12056
# cons.conf.idx     12056
# euribor3m         12056
# nr.employed       12056
# target            12056
# dtype: int64

# %%
X_train_up = upsampled.drop('target',axis=1)
y_train_up = upsampled['target']

# %% [markdown]
# <b>
# <font color="red">Logistic Regression on Upsampled data</font>
# </b>

# %%
log_up = LogisticRegression()
log_up.fit(X_train_up, y_train_up)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_up = log_up.predict(X_test)

# %%
print(classification_report(y_test, pred_up))
print(confusion_matrix(y_test, pred_up))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91     24492
#            1       0.42      0.85      0.56      3103
#
#     accuracy                           0.85     27595
#    macro avg       0.70      0.85      0.74     27595
# weighted avg       0.92      0.85      0.87     27595
#
# [[20864  3628]
#  [  475  2628]]

# %% [markdown]
# <b>
# <font color="red">Random Forest on Upsampled data</font>
# </b>

# %%
rfc_up = RandomForestClassifier(n_estimators=5000)

# %%
rfc_up.fit(X_train_up, y_train_up)
pred_rfc_up = rfc_up.predict(X_test)

# %%
print(classification_report(y_test, pred_rfc_up))
print(confusion_matrix(y_test, pred_rfc_up))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     24492
#            1       0.59      0.62      0.61      3103
#
#     accuracy                           0.91     27595
#    macro avg       0.77      0.78      0.78     27595
# weighted avg       0.91      0.91      0.91     27595
#
# [[23143  1349]
#  [ 1170  1933]]

# %% [markdown]
# <b>
# <font color="green">Downsampling of majority</font>
# </b>

# %%
target_no_downsampled = resample(target_no,replace=True, n_samples=len(target_yes), random_state=27)

# %%
downsampled = pd.concat([target_yes, target_no_downsampled])

# %%
X_train_down = downsampled.drop('target', axis=1)

# %%
y_train_down = downsampled['target']

# %% [markdown]
# <b>
# <font color="green">Logistic Regression on Downsampled data</font>
# </b>

# %%
log_down = LogisticRegression()
log_down.fit(X_train_down, y_train_down)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_down = log_down.predict(X_test)

# %% [markdown]
# <b>
# <font color="green">Random Forest on Downsampled data</font>
# </b>

# %%
rfc_down = RandomForestClassifier(n_estimators=5000)

# %%
rfc_down.fit(X_train_down, y_train_down)
pred_rfc_down = rfc_down.predict(X_test)

# %%
print(classification_report(y_test, pred_rfc_down))
print(confusion_matrix(y_test, pred_rfc_down))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.83      0.90     24492
#            1       0.41      0.93      0.57      3103
#
#     accuracy                           0.84     27595
#    macro avg       0.70      0.88      0.74     27595
# weighted avg       0.92      0.84      0.87     27595
#
# [[20424  4068]
#  [  222  2881]]

# %% [markdown]
# <b>
# <font color="blue">USING SMOTE</font>
# </b>

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=27)

# %%
X_train_smote, y_train_smote = sm.fit_sample(X_train, y_train)

# %% [markdown]
# <b>
# <font color="blue">Logistic Regression on SMOTE Data</font>
# </b>

# %%
log_smote = LogisticRegression()
log_smote.fit(X_train_smote, y_train_smote)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred_smote = log_smote.predict(X_test)

# %%
print(classification_report(y_test, pred_smote))
print(confusion_matrix(y_test, pred_smote))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91     24492
#            1       0.41      0.83      0.55      3103
#
#     accuracy                           0.85     27595
#    macro avg       0.69      0.84      0.73     27595
# weighted avg       0.91      0.85      0.87     27595
#
# [[20854  3638]
#  [  537  2566]]

# %% [markdown]
# <b>
# <font color="blue">Random Forest on SMOTE Data</font>
# </b>

# %%
rfc_smote = RandomForestClassifier(n_estimators=500)

# %%
rfc_smote.fit(X_train_smote, y_train_smote)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
pred_rfc_smote = rfc_smote.predict(X_test)

# %%
print(classification_report(y_test, pred_rfc_smote))
print(confusion_matrix(y_test, pred_rfc_smote))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     24492
#            1       0.57      0.64      0.60      3103
#
#     accuracy                           0.91     27595
#    macro avg       0.76      0.79      0.78     27595
# weighted avg       0.91      0.91      0.91     27595
#
# [[22990  1502]
#  [ 1109  1994]]

# %% [markdown]
# <b>
# <font color="purple">Comparing performance of various Resampling Techniques</font>
# </b>

# %% [markdown]
# <b>
# <font color="green"> 1. f1-score </font>
# </b>

# %%
list = [predictions, pred_up, pred_down, pred_smote, predictions_rfc, pred_rfc_up, pred_rfc_down, pred_rfc_smote]

# %%
from sklearn.metrics import f1_score

# %%
F1_score = []
for i in list:
    F1_score.append(f1_score(y_test, i))

# %%
F1 = pd.DataFrame(data= {'Classifier':['Logistic','Logistic','Logistic','Logistic', 'Random Forest','Random Forest', 'Random Forest', 'Random Forest'],'Technique':['Orginal', 'Upscaling Minority', 'Downscaling Majority', 'SMOTE','Orginal', 'Upscaling Minority', 'Downscaling Majority', 'SMOTE'], 'f1-score':F1_score})

# %%
F1
# Out:
#       Classifier             Technique  f1-score
# 0       Logistic               Orginal  0.486802
# 1       Logistic    Upscaling Minority  0.561598
# 2       Logistic  Downscaling Majority  0.559831
# 3       Logistic                 SMOTE  0.551413
# 4  Random Forest               Orginal  0.573511
# 5  Random Forest    Upscaling Minority  0.605482
# 6  Random Forest  Downscaling Majority  0.573219
# 7  Random Forest                 SMOTE  0.604334

# %%
plt.figure(figsize=(18,8))
sns.barplot(x='Technique', y='f1-score',hue='Classifier', data=F1)

# %% [markdown]
# <b>
# <font color="green"> 2. Accuracy </font>
# </b>

# %%
from sklearn.metrics import accuracy_score

# %%
Accuracy=[]

for i in list:
    Accuracy.append(accuracy_score(y_test,i))

# %%
AS = pd.DataFrame(data= {'Classifier':['Logistic','Logistic','Logistic','Logistic', 'Random Forest','Random Forest', 'Random Forest', 'Random Forest'],'Technique':['Orginal', 'Upscaling Minority', 'Downscaling Majority', 'SMOTE','Orginal', 'Upscaling Minority', 'Downscaling Majority', 'SMOTE'], 'accuracy-score':Accuracy})

# %%
AS
# Out:
#       Classifier             Technique  accuracy-score
# 0       Logistic               Orginal        0.907701
# 1       Logistic    Upscaling Minority        0.851314
# 2       Logistic  Downscaling Majority        0.848704
# 3       Logistic                 SMOTE        0.848704
# 4  Random Forest               Orginal        0.913064
# 5  Random Forest    Upscaling Minority        0.908715
# 6  Random Forest  Downscaling Majority        0.844537
# 7  Random Forest                 SMOTE        0.905381

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='Technique', y='accuracy-score',hue='Classifier', data=AS)
